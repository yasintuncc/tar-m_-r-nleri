# %% [markdown]
# <a href="https://colab.research.google.com/github/yasintuncc/tar-m_-r-nleri/blob/main/Tar%C4%B1m_%C3%9Cr%C3%BCnleri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarım Ürünleri Projesi

# %%
import geopandas as gpd
import pandas as pd

# %%
gdf = gpd.read_file("/content/drive/MyDrive/Colab Notebooks/Ağ Projesi/Veriler/shp/TUR_adm1.shp")

# %%
gdf
# Out:
#     ID_0  ISO  NAME_0  ID_1     NAME_1 TYPE_1 ENGTYPE_1 NL_NAME_1  \
# 0    235  TUR  Turkey     1  Çanakkale     Il  Province      None
# 1    235  TUR  Turkey     2    Çankiri     Il  Province      None
# 2    235  TUR  Turkey     3      Çorum     Il  Province      None
# 3    235  TUR  Turkey     4      Adana     Il  Province      None
# 4    235  TUR  Turkey     5   Adiyaman     Il  Province      None
# ..   ...  ...     ...   ...        ...    ...       ...       ...
# 76   235  TUR  Turkey    77       Usak     Il  Province      None
# 77   235  TUR  Turkey    78        Van     Il  Province      None
# 78   235  TUR  Turkey    79     Yalova     Il  Province      None
# 79   235  TUR  Turkey    80     Yozgat     Il  Province      None
# 80   235  TUR  Turkey    81  Zinguldak     Il  Province      None
#
#           VARNAME_1                                           geometry
# 0              None  MULTIPOLYGON (((26.05347 39.84736, 26.05347 39...
# ...

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ağ Projesi/Veriler/migration-city-data.csv')

# %%
df
# Out:
#               city   value
# 0            Adana   55018
# 1         Adıyaman   18780
# 2   Afyonkarahisar   23667
# 3          Aksaray   14264
# 4           Amasya   15217
# ..             ...     ...
# 76           Çorum   18723
# 77        İstanbul  385294
# 78           İzmir  132426
# 79       Şanlıurfa   45648
# 80          Şırnak   20096
#
# [81 rows x 2 columns]

# %%
replace_map = {
    'K. Maras': 'Kahramanmaras',
    'Kinkkale': 'Kirikkale',
    'Zinguldak': 'Zonguldak',
    'Afyon': 'Afyonkarahisar'
}

gdf['NAME_1'] = gdf['NAME_1'].replace(replace_map)

# %%
turkish_chars = {
    'İ':'I',
    'ı':'i',
    'Ş':'S',
    'ş':'s',
    'Ğ':'G',
    'ğ':'g',
    'Ü':'U',
    'ü':'u',
    'Ö':'O',
    'ö':'o',
    'Ç':'C',
    'ç':'c',
}
translation_table = str.maketrans(turkish_chars)

df['city'] = df['city'].str.translate(translation_table)
gdf['NAME_1'] = gdf['NAME_1'].str.translate(translation_table)

# %%
gdf
# Out:
#     ID_0  ISO  NAME_0  ID_1     NAME_1 TYPE_1 ENGTYPE_1 NL_NAME_1  \
# 0    235  TUR  Turkey     1  Canakkale     Il  Province      None
# 1    235  TUR  Turkey     2    Cankiri     Il  Province      None
# 2    235  TUR  Turkey     3      Corum     Il  Province      None
# 3    235  TUR  Turkey     4      Adana     Il  Province      None
# 4    235  TUR  Turkey     5   Adiyaman     Il  Province      None
# ..   ...  ...     ...   ...        ...    ...       ...       ...
# 76   235  TUR  Turkey    77       Usak     Il  Province      None
# 77   235  TUR  Turkey    78        Van     Il  Province      None
# 78   235  TUR  Turkey    79     Yalova     Il  Province      None
# 79   235  TUR  Turkey    80     Yozgat     Il  Province      None
# 80   235  TUR  Turkey    81  Zonguldak     Il  Province      None
#
#           VARNAME_1                                           geometry
# 0              None  MULTIPOLYGON (((26.05347 39.84736, 26.05347 39...
# ...

# %%
gdf = gdf.merge(df, how='left', left_on='NAME_1', right_on='city')

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf
# Out:
#     ID_0  ISO  NAME_0  ID_1     NAME_1 TYPE_1 ENGTYPE_1 NL_NAME_1  \
# 0    235  TUR  Turkey     1  Canakkale     Il  Province      None
# 1    235  TUR  Turkey     2    Cankiri     Il  Province      None
# 2    235  TUR  Turkey     3      Corum     Il  Province      None
# 3    235  TUR  Turkey     4      Adana     Il  Province      None
# 4    235  TUR  Turkey     5   Adiyaman     Il  Province      None
# ..   ...  ...     ...   ...        ...    ...       ...       ...
# 76   235  TUR  Turkey    77       Usak     Il  Province      None
# 77   235  TUR  Turkey    78        Van     Il  Province      None
# 78   235  TUR  Turkey    79     Yalova     Il  Province      None
# 79   235  TUR  Turkey    80     Yozgat     Il  Province      None
# 80   235  TUR  Turkey    81  Zonguldak     Il  Province      None
#
#           VARNAME_1                                           geometry  \
# 0              None  MULTIPOLYGON (((26.05347 39.84736, 26.05347 39...
# ...

# %%
import matplotlib.patheffects as pe
import matplotlib.pyplot as plt

ax = gdf.plot(
    column="value",
    cmap="Blues",
    figsize=(20,10),
    edgecolor='gray',
    linewidth=0.5
)

ax.set_axis_off()

for x, y, city_name in zip(gdf['geometry'].centroid.x, gdf['geometry'].centroid.y, gdf['city']):
    ax.text(
        x, y, city_name, fontsize=8, path_effects=[pe.withStroke(linewidth=2, foreground='white')]
    )

ax.set_title(
    "İLLER BAZINDA TARIM ÜRÜNLERİ",
    fontsize=18,
    fontdict={"fontweight":'bold'}
)


# export

plt.savefig(
    "sehir-bazli-goc-2022.png",
    dpi=300,
    bbox_inches='tight'
)
# Out:
# <ipython-input-16-80ce88b79c7d>:14: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   for x, y, city_name in zip(gdf['geometry'].centroid.x, gdf['geometry'].centroid.y, gdf['city']):
